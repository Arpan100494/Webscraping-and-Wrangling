# %%
import tweepy

# %%
consumer_key = "0p0FonTDUYemNfPg8epMh6kFO"
consumer_secret = "wPe8tcxhP63cseioDcWeOkj77SdWrNMaXJPQUz2QzKO8LscL25"

access_token = "991382693945360386-doRMFJghJAPN9Krhqc5tSdu6fU9fuby"
access_secret = "xYfzST5UEPDz0WGBUTnEdRCczVk4qSGTt7uKcO2at5iJU"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

# %%
followers_status = api.followers("narendramodi", count=200)
len(followers_status)
# Out:
# 200

# %%
users = api.search_users("chowkidar",count=200)
len(users)
# Out:
# 20

# %%
# for checking the limit
#api.rate_limit_status()

# %%
followers_status[0]._json
# Out:
# {'id': 1112922919515156480,
#  'id_str': '1112922919515156480',
#  'name': 'Meharam Choudhary RLP',
#  'screen_name': 'MeharamRlp',
#  'location': '',
#  'description': '',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 0,
#  'friends_count': 5,
#  'listed_count': 0,
#  'created_at': 'Tue Apr 02 03:41:15 +0000 2019',
#  'favourites_count': 0,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 0,
#  'lang': 'en',
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1112923198906142720/AKer3m-f_normal.jpg',
# ...

# %%
for follower in followers_status:
    print(follower.name, follower.location)
# Out:
# Meharam Choudhary RLP
# Sain Rj Shastri Nagar
# Aishwarya Mishra
# nikhil sahu bijadandi (mandla)
# Vishal
# Wong LEE
# Vigneshbarani
# Abhishek Maurya
# I M Raj
# Anita Kumari Singhania
# Gajendra pareek
# Prakash P Soraganvi
# Sudarshan S
# Rajesh Kadbe
# rawat
# Ravi
# Sai_Kiran
# Vikash Tiwari
# Gopi Nath
# Nagendra Singh
# Sridhar panda BHUBANESWAR
# Mohd Sufiyan
# Himanshu Kolwal
# Vikram Kumar Sah
# Anil Choudhary
# Mukesh
# vidhansingh5790@gamil.com
# Majid Zahir
# S.V.
# tauqueeranwar
# Balasubramanian Balu Tamil Nadu, India
# Nasim
# Gopal
# Narayan Tiwary
# Suvarna Patil
# Mahant Aakash Giri
# Nitin yadav ji
# NITIN SURYA
# Pradip Kumar
# social741_aakank
# Anil Panchal Indore, India
# mdnambiar md
# bhasker reddy
# Jadumani bag
# darling uthej
# FIGHTER  AJEET SINGH
# jitender vyas
# Malik Ankur
# Prashanth
# Avishek kumar
# Dhruv Maheshwari
# কংকন ৰাজবংশী
# Shyam Sundar Modi
# Sonu Maharaj
# Sagar Bihar, India
# Sahil Shane
# Vinay Kumar
# Sandeep Kumar
# ...

# %%
#run server twiteer will tweet to u which is in twitter streaming.py
import os
os.getcwd()
# Out:
# 'D:\\Arpan_Python_Programming\\DataScraping & Data Wrangling'

# %%
import glob
glob.glob("*.csv")
# Out:
# ['jobs_datascience.csv', 'ModiTweets.csv']

# %%
file_name = "tweets_datascience.csv"
file_exist = file_name in glob.glob("*.csv")
file_exist
# Out:
# False

# %%
import pandas as pd

# %% [markdown]
# ## take the live tweeter stream and append to csv file

# %%
file_name = "temp.csv"
file_exist = file_name in glob.glob("*.csv")

df = pd.DataFrame({"x":[1,2,3],"y":[4,5,6]})

if file_exist:
    #append the data
    with open(file_name, "a") as f:
        df.to_csv(f, index=False, header=False)
else:
    #create a new file
    df.to_csv(file_name, index=False)

# %% [markdown]
# # DATA QUALITY

# %%
naukri_data = pd.read_csv("naukri_jobs_datascience.csv")
naukri_data.head()
# Out:
#              id                                      title  \
# 0  280918001664                               Data Science
# 1  280818003404       Analyst / Sr. Analyst (data Science)
# 2  280918008755                    ETL Lead & Data Science
# 3  270918901342                  Specialist - Data Science
# 4  260918002450  Group Manager - Data Science - Python/nlp
#
#                                   location experience  \
# 0                                   Mumbai    2-4 yrs
# 1                                  Gurgaon    5-8 yrs
# 2  Chennai, Bengaluru, Mumbai, Pune, Noida   7-10 yrs
# 3            Delhi NCR, Bengaluru, Gurgaon   7-12 yrs
# 4                                Bengaluru   6-11 yrs
#
#                                               skills  \
# 0  Algorithms, Machine Learning, Python, Java, Da...
# 1  predictive modeling, predictive analytics, mac...
# 2  SQL, Data Analysis, Text Mining, SAS, R, Stati...
# 3  Specialist - Data Science, Data Science, data ...
# ...

# %%
naukri_data.isnull().sum()/len(naukri_data)*100
# Out:
# id              0.000
# title           0.000
# location        0.000
# experience      0.575
# skills          1.125
# company         0.000
# salary          0.000
# description    59.225
# posted_date     0.000
# type            0.000
# url             0.000
# dtype: float64

# %%
naukri_data.experience[0]
# Out:
# '2-4 yrs'

# %%
x = naukri_data.experience[0]
min_exp = x.split("-")[0]
min_exp
# Out:
# '2'

# %%
max_exp = x.split("-")[1].split(" ")[0]
max_exp
# Out:
# '4'

# %% [markdown]
# ## printing whcih row has missing value

# %%
def temp(row):
    if type(row["experience"])==str:
        pass
    else:
        print(row.name, row["experience"])
        
naukri_data.apply(lambda row:temp(row), axis=1)
# Out:
# 132 nan
# 134 nan
# 136 nan
# 138 nan
# 140 nan
# 143 nan
# 144 nan
# 543 nan
# 1485 nan
# 1496 nan
# 1501 nan
# 1503 nan
# 1515 nan
# 1516 nan
# 1520 nan
# 1521 nan
# 1525 nan
# 1527 nan
# 1528 nan
# 2112 nan
# 2113 nan
# 2150 nan
# 2208 nan
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14      None
# 15      None
# 16      None
# 17      None
# 18      None
# 19      None
# 20      None
# 21      None
# 22      None
# 23      None
# 24      None
# 25      None
# 26      None
# 27      None
# 28      None
# 29      None
#         ...
# 3970    None
# 3971    None
# 3972    None
# 3973    None
# 3974    None
# 3975    None
# 3976    None
# 3977    None
# 3978    None
# 3979    None
# 3980    None
# 3981    None
# 3982    None
# 3983    None
# 3984    None
# 3985    None
# 3986    None
# 3987    None
# 3988    None
# ...

# %% [markdown]
# # extracting min and max exp from experience column using lambda

# %%
naukri_data["min_exp"]= naukri_data.experience.apply(
    lambda x : float("nan") if type(x) != str  else x.split("-")[0]).astype(float)

# %%
naukri_data["max_exp"]= naukri_data.experience.apply(
    lambda x : float("nan") if type(x) != str  else x.split("-")[1].split(" ")[0]).astype(float)

# %%
naukri_data[["experience","min_exp","max_exp"]].head()
# Out:
#   experience  min_exp  max_exp
# 0    2-4 yrs      2.0      4.0
# 1    5-8 yrs      5.0      8.0
# 2   7-10 yrs      7.0     10.0
# 3   7-12 yrs      7.0     12.0
# 4   6-11 yrs      6.0     11.0

# %%
naukri_data.dtypes
# Out:
# id               int64
# title           object
# location        object
# experience      object
# skills          object
# company         object
# salary          object
# description     object
# posted_date     object
# type            object
# url             object
# min_exp        float64
# max_exp        float64
# dtype: object

# %%
# %matplotlib inline
naukri_data.min_exp.plot(kind="box")

# %%
naukri_data.salary.unique()
# Out:
# array(['    2,00,000 - 7,00,000 P.A.  ',
#        '    5,00,000 - 10,00,000 P.A.  ',
#        '    10,00,000 - 15,00,000 P.A.  ', '  Not disclosed ',
#        '    2,00,000 - 4,25,000 P.A.  ', '    4,00,000 - 8,00,000 P.A.  ',
#        '    1,00,000 - 3,00,000 P.A.  ', '    1,25,000 - 3,00,000 P.A.  ',
#        '    1,25,000 - 4,00,000 P.A. Best salary as per Industry & ...  ',
#        '    2,50,000 - 7,50,000 P.A.  ', '    4,00,000 - 7,50,000 P.A.  ',
#        '    22,50,000 - 35,00,000 P.A.  ',
#        '    12,00,000 - 18,00,000 P.A.  ',
#        '    13,00,000 - 20,00,000 P.A.  ',
#        '    3,00,000 - 8,00,000 P.A. 40%  ',
#        '    8,00,000 - 10,00,000 P.A.  ',
#        '    1,00,000 - 4,00,000 P.A.  ', '    50,000 - 2,00,000 P.A.  ',
#        '    7,00,000 - 17,00,000 P.A.  ',
#        '    6,00,000 - 12,00,000 P.A.  ',
#        '    10,00,000 - 20,00,000 P.A.  ', '    Rs. 1.50 Lac/month  ',
#        '    PB-3 Rs15600-39100 with minimum pay of Rs30000 + AGP of...  ',
# ...

# %%
naukri_data[naukri_data.salary.str.contains("Not disclosed")].shape
# Out:
# (3474, 13)

# %%
#opposite of above
sal = naukri_data[~naukri_data.salary.str.contains("Not disclosed")]

sal["salary_new"] = sal["salary"].str.replace(",",'')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
naukri_data["salary_new"] = naukri_data.salary.str.replace(",",'')
naukri_data.head()
# Out:
#              id                                      title  \
# 0  280918001664                               Data Science
# 1  280818003404       Analyst / Sr. Analyst (data Science)
# 2  280918008755                    ETL Lead & Data Science
# 3  270918901342                  Specialist - Data Science
# 4  260918002450  Group Manager - Data Science - Python/nlp
#
#                                   location experience  \
# 0                                   Mumbai    2-4 yrs
# 1                                  Gurgaon    5-8 yrs
# 2  Chennai, Bengaluru, Mumbai, Pune, Noida   7-10 yrs
# 3            Delhi NCR, Bengaluru, Gurgaon   7-12 yrs
# 4                                Bengaluru   6-11 yrs
#
#                                               skills  \
# 0  Algorithms, Machine Learning, Python, Java, Da...
# 1  predictive modeling, predictive analytics, mac...
# 2  SQL, Data Analysis, Text Mining, SAS, R, Stati...
# 3  Specialist - Data Science, Data Science, data ...
# ...

# %%
naukri_data["is_sal"] = naukri_data["salary_new"].str.contains("(\d+ - \d+) P.A.")

naukri_data["min"] = naukri_data.apply(lambda row:row.salary_new.split(" ")[0] if row.is_sal else "nan", axis=1).astype(float)
naukri_data["max"] = naukri_data.apply(lambda row:row.salary_new.split(" ")[2] if row.is_sal else "nan", axis=1).astype(float)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-b96cb4c2c8a4> in <module>
#       1 naukri_data["is_sal"] = naukri_data["salary_new"].str.contains("(\d+ - \d+) P.A.")
#       2
# ----> 3 naukri_data["min"] = naukri_data.apply(lambda row:row.salary_new.split(" ")[0] if row.is_sal else "nan", axis=1).astype(float)
#       4 naukri_data["max"] = naukri_data.apply(lambda row:row.salary_new.split(" ")[2] if row.is_sal else "nan", axis=1).astype(float)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# ...

# %%
naukri_data["is_sal"] = naukri_data[naukri_data["salary_new"].str.contains("(\d+ - \d+) P.A.")]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.

# %%
# Out:
#                 id                                              title  \
# 0     280918001664                                       Data Science
# 1     280818003404               Analyst / Sr. Analyst (data Science)
# 2     280918008755                            ETL Lead & Data Science
# 3     270918901342                          Specialist - Data Science
# 4     260918002450          Group Manager - Data Science - Python/nlp
# 5     270918000257  Data Analyst / Data Science - Excel,sql,sas,py...
# 6     270918002661                               Trainee Data Science
# 7     260918001552                  Solution Architect - Data Science
# 8     250918900817                            Director - Data Science
# 9     250918900279           Data Science Engineer - Machine Learning
# 10    240918900946                 Data Science Research Manager - IT
# 11    170818003319  Urgent Hiring for Full Time Trainer in DATA Sc...
# ...

# %%
import re
re.findall("(\d+ - \d+) P.A","500000 - 1000000 P.A. Very competitive sal")
# Out:
# ['500000 - 1000000']

# %%
ls = []
for i in naukri_data["salary_new"]:
    x = re.findall("\d+ - \d+",i)
    ls.extend(x)
sal["clean_sal"] = pd.Series(ls)

# %%
bins = [0.1,2,5,10,20]
